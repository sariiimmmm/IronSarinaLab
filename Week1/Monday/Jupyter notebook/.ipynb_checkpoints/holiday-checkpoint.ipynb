# %% [markdown]
# # Holiday

# %% [markdown]
# *describing a holiday in this notebook using markdown*

# %% [markdown]
# ### Content

# %% [markdown]
# 1.[Holiday Image](#Holiday-destination)
#
# 2.[Activities during Holiday](#Acticities-I-prefer-to-do)
#
# 3.[Holiday Destination Video](#Video)

# %%
x=input('Please Enter your name:')
# Out:
# Please Enter your name:Sarina

# %%
print("this is about" + " "+ x +"'s "+"holiday")
# Out:
# this is about Sarina's holiday

# %% [markdown]
# # Input function
# >x=input('Please Enter your name:') <br> >print("this is about" + " "+ x +"'s "+"holiday")

# %% [markdown]
# -------------

# %% [markdown]
# ## Image

# %% [markdown]
# ## **Holiday destination**

# %% [markdown]
# ![A.jpeg](attachment:A.jpeg)

# %% [markdown]
# ## Acticities I prefer to do

# %% [markdown]
# - Swiming in sea
# - read book under the sun and taking sunbath
# - drinking cocktail

# %% [markdown]
# ### Video

# %% [markdown]
# [you can watch the top 10 holiday destination by clicking here](https://www.youtube.com/embed/h_xjfqrFl7o)
