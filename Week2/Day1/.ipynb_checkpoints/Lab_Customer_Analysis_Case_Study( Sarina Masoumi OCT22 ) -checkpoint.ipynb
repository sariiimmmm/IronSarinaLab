# %% [markdown]
# # Lab Case Study
#
# ## Scenario
#
# You are working as an analyst for an auto insurance company. The company has collected some data about its customers including their demographics, education, employment, policy details, vehicle information on which insurance policy is, and claim amounts. You will help the senior management with some business questions that will help them to better understand their customers, improve their services, and improve profitability.
#
# ## Business Objectives
#
# - Retain customers,
# - analyze relevant customer data,
# - develop focused customer retention programs.
#
# Based on the analysis, take targeted actions to increase profitable customer response, retention, and growth.
#
# ## Activities
#
# Refer to the [`Activities.md`](./Activities.md) file where you will find guidelines for some of the activities that you want to do.
#
# ## Data
#
# The csv files is provided in the folder. The columns in the file are self-explanatory.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import statsmodels.api as sm
from scipy.stats import boxcox
pd.options.display.max_rows = 100

# %%
def load_original_data():
    file1 = pd.read_csv('Data/file1.csv')
    file2 = pd.read_csv('Data/file2.csv')
    file3 = pd.read_csv('Data/file3.csv')
    return pd.concat([file1,file2,file3], axis=0)

# %%
auto_insurance=load_original_data()
auto_insurance=auto_insurance.reset_index()
auto_insurance
# Out:
#        index Customer          ST GENDER             Education  \
# 0          0  RB50392  Washington    NaN                Master
# 1          1  QZ44356     Arizona      F              Bachelor
# 2          2  AI49188      Nevada      F              Bachelor
# 3          3  WW63253  California      M              Bachelor
# 4          4  GA49547  Washington      M  High School or Below
# ...      ...      ...         ...    ...                   ...
# 12069   7065  LA72316         NaN    NaN              Bachelor
# 12070   7066  PK87824         NaN    NaN               College
# 12071   7067  TD14365         NaN    NaN              Bachelor
# 12072   7068  UP19263         NaN    NaN               College
# 12073   7069  Y167826         NaN    NaN               College
#
#       Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                         NaN      0.0                1000.0
# 1                  697953.59%      0.0                  94.0
# ...

# %%
def lower_case_columns(x):
    x.columns=[i.lower() for i in x.columns]
    return x

# %%
list(auto_insurance.columns)
# Out:
# ['index',
#  'Customer',
#  'ST',
#  'GENDER',
#  'Education',
#  'Customer Lifetime Value',
#  'Income',
#  'Monthly Premium Auto',
#  'Number of Open Complaints',
#  'Policy Type',
#  'Vehicle Class',
#  'Total Claim Amount',
#  'State',
#  'Gender']

# %%
auto_insurance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12074 entries, 0 to 12073
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   index                      12074 non-null  int64
#  1   Customer                   9137 non-null   object
#  2   ST                         2067 non-null   object
#  3   GENDER                     1945 non-null   object
#  4   Education                  9137 non-null   object
#  5   Customer Lifetime Value    9130 non-null   object
#  6   Income                     9137 non-null   float64
#  7   Monthly Premium Auto       9137 non-null   float64
#  8   Number of Open Complaints  9137 non-null   object
#  9   Policy Type                9137 non-null   object
#  10  Vehicle Class              9137 non-null   object
#  11  Total Claim Amount         9137 non-null   float64
#  12  State                      7070 non-null   object
# ...

# %%
auto_insurance["Gender"]=auto_insurance['Gender'].fillna(auto_insurance["GENDER"])
auto_insurance["State"]=auto_insurance['State'].fillna(auto_insurance["ST"])
auto_insurance
# Out:
#        index Customer          ST GENDER             Education  \
# 0          0  RB50392  Washington    NaN                Master
# 1          1  QZ44356     Arizona      F              Bachelor
# 2          2  AI49188      Nevada      F              Bachelor
# 3          3  WW63253  California      M              Bachelor
# 4          4  GA49547  Washington      M  High School or Below
# ...      ...      ...         ...    ...                   ...
# 12069   7065  LA72316         NaN    NaN              Bachelor
# 12070   7066  PK87824         NaN    NaN               College
# 12071   7067  TD14365         NaN    NaN              Bachelor
# 12072   7068  UP19263         NaN    NaN               College
# 12073   7069  Y167826         NaN    NaN               College
#
#       Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                         NaN      0.0                1000.0
# 1                  697953.59%      0.0                  94.0
# ...

# %%
auto_insurance.drop_duplicates()
# Out:
#        index Customer          ST GENDER             Education  \
# 0          0  RB50392  Washington    NaN                Master
# 1          1  QZ44356     Arizona      F              Bachelor
# 2          2  AI49188      Nevada      F              Bachelor
# 3          3  WW63253  California      M              Bachelor
# 4          4  GA49547  Washington      M  High School or Below
# ...      ...      ...         ...    ...                   ...
# 12069   7065  LA72316         NaN    NaN              Bachelor
# 12070   7066  PK87824         NaN    NaN               College
# 12071   7067  TD14365         NaN    NaN              Bachelor
# 12072   7068  UP19263         NaN    NaN               College
# 12073   7069  Y167826         NaN    NaN               College
#
#       Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                         NaN      0.0                1000.0
# 1                  697953.59%      0.0                  94.0
# ...

# %%
def drop_columns(x,a) :
    x.drop(columns=[a], inplace=True)
    return x

# %%
drop_columns(auto_insurance,"GENDER")
drop_columns(auto_insurance,"ST")
# Out:
#        index Customer             Education Customer Lifetime Value   Income  \
# 0          0  RB50392                Master                     NaN      0.0
# 1          1  QZ44356              Bachelor              697953.59%      0.0
# 2          2  AI49188              Bachelor             1288743.17%  48767.0
# 3          3  WW63253              Bachelor              764586.18%      0.0
# 4          4  GA49547  High School or Below              536307.65%  36357.0
# ...      ...      ...                   ...                     ...      ...
# 12069   7065  LA72316              Bachelor             23405.98798  71941.0
# 12070   7066  PK87824               College             3096.511217  21604.0
# 12071   7067  TD14365              Bachelor             8163.890428      0.0
# 12072   7068  UP19263               College             7524.442436  21941.0
# 12073   7069  Y167826               College             2611.836866      0.0
#
# ...

# %%
list(auto_insurance.columns)
# Out:
# ['index',
#  'Customer',
#  'Education',
#  'Customer Lifetime Value',
#  'Income',
#  'Monthly Premium Auto',
#  'Number of Open Complaints',
#  'Policy Type',
#  'Vehicle Class',
#  'Total Claim Amount',
#  'State',
#  'Gender']

# %%
lower_case_columns(auto_insurance)
auto_insurance
# Out:
#        index customer             education customer lifetime value   income  \
# 0          0  RB50392                Master                     NaN      0.0
# 1          1  QZ44356              Bachelor              697953.59%      0.0
# 2          2  AI49188              Bachelor             1288743.17%  48767.0
# 3          3  WW63253              Bachelor              764586.18%      0.0
# 4          4  GA49547  High School or Below              536307.65%  36357.0
# ...      ...      ...                   ...                     ...      ...
# 12069   7065  LA72316              Bachelor             23405.98798  71941.0
# 12070   7066  PK87824               College             3096.511217  21604.0
# 12071   7067  TD14365              Bachelor             8163.890428      0.0
# 12072   7068  UP19263               College             7524.442436  21941.0
# 12073   7069  Y167826               College             2611.836866      0.0
#
# ...

# %%
auto_insurance.state.unique()
# Out:
# array(['Washington', 'Arizona', 'Nevada', 'California', 'Oregon', 'Cali',
#        'AZ', 'WA', nan], dtype=object)

# %%
auto_insurance.gender.unique()
# Out:
# array([nan, 'F', 'M', 'Femal', 'Male', 'female'], dtype=object)

# %%
def clean_gender(x):
    if x in ['M', 'MALE',"male"]:
        return 'Male'
    elif x in ['F', 'female',"male"]:
        return 'Female'
    elif np.nan:  pass
    else:
        return 'U'

# %%
auto_insurance['gender'] = list(map(clean_gender, auto_insurance['gender'])) 
auto_insurance
# Out:
#        index customer             education customer lifetime value   income  \
# 0          0  RB50392                Master                     NaN      0.0
# 1          1  QZ44356              Bachelor              697953.59%      0.0
# 2          2  AI49188              Bachelor             1288743.17%  48767.0
# 3          3  WW63253              Bachelor              764586.18%      0.0
# 4          4  GA49547  High School or Below              536307.65%  36357.0
# ...      ...      ...                   ...                     ...      ...
# 12069   7065  LA72316              Bachelor             23405.98798  71941.0
# 12070   7066  PK87824               College             3096.511217  21604.0
# 12071   7067  TD14365              Bachelor             8163.890428      0.0
# 12072   7068  UP19263               College             7524.442436  21941.0
# 12073   7069  Y167826               College             2611.836866      0.0
#
# ...

# %%
def clean_city(x):
    if x in ['WA', "Washington"]:
        return "Washington"
    elif x in ["Arizona","AZ"]:
        return "Arizona"
    elif x in ["California","Cali"]:
        return "California"
    elif np.nan:  pass
    else:
        return 'U'

# %%
auto_insurance["state"] = list(map(clean_city, auto_insurance["state"])) 
auto_insurance
# Out:
#        index customer             education customer lifetime value   income  \
# 0          0  RB50392                Master                     NaN      0.0
# 1          1  QZ44356              Bachelor              697953.59%      0.0
# 2          2  AI49188              Bachelor             1288743.17%  48767.0
# 3          3  WW63253              Bachelor              764586.18%      0.0
# 4          4  GA49547  High School or Below              536307.65%  36357.0
# ...      ...      ...                   ...                     ...      ...
# 12069   7065  LA72316              Bachelor             23405.98798  71941.0
# 12070   7066  PK87824               College             3096.511217  21604.0
# 12071   7067  TD14365              Bachelor             8163.890428      0.0
# 12072   7068  UP19263               College             7524.442436  21941.0
# 12073   7069  Y167826               College             2611.836866      0.0
#
# ...
